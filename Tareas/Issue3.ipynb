# %% [markdown]
# # Loop Replacement y keywords

# %% [markdown]
# ## 1 - Realizar la Tarea 2 usando Python
# Código para subir la base de datos excel en Python
# Solo debe ajustar el directorio
# junin_data = pd.read_excel("../data/Region_Junin.xlsx")

# %%
# Primero importamos las librerías necesarias

import numpy as np
import pandas as pd
from pandas import DataFrame,Series
import os # for usernanme 


# Construimos el directorio donde se trabajará

user = os.getlogin()   # Username
print(user)

# Set directorio

os.chdir(f"/Users/henryandreumarquezsalinas/Documents/GitHub/First-Repository/Lab3") # Set directorio

df = pd.read_excel("../Region_Junin.xlsx", index_col=0) # Subir base de datos
df
# Out:
# henryandreumarquezsalinas
#     Region          District               Place  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1    JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2    JUNIN  CIUDAD DEL CERRO                VICO              1
# 3    JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4    JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..     ...               ...                 ...            ...
# 192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193  JUNIN             YAULI         P.POMACOCHA              1
# 194  JUNIN             YAULI                 NaN              2
# 195  JUNIN             YAULI               YAULI              2
# 196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111           297.0               171
# ...

# %% [markdown]
# ## Exploring a DataFrame

# %% [markdown]
# #### 1. Obtener el nombre de todas las variables

# %%
df.columns
# Out:
# Index(['Region', 'District', 'Place', '4_6_years_men', '4_6_years_women',
#        '4_6_years_total', '6_14_years_men', '6_14_years_women',
#        '6_14_years_total', 'man_read', 'women_read', 'total_read',
#        'men_not_read', 'women_not_read', 'total_not_read', 'man_write',
#        'women_write', 'total_write', 'men_not_write', 'women_not_write',
#        'total_not_write', 'instruction_men', 'instruction_women',
#        'instruction_total', 'no_instruction_men', 'no_instruction_women',
#        'no_instruction_total', 'finished_instr_men', 'finished_instr_women',
#        'finished_instr_total', 'not_finished_instr_men',
#        'not_finished_instr_women', 'not_finished_instr_total', 'peruvian_men',
#        'peruvian_women', 'foreign_men', 'foreign_women', 'whites', 'natives',
#        'mestizos', 'blacks'],
#       dtype='object')

# %% [markdown]
# #### 2. Mostrar el tipo de variables (type) así como presentar los principales estadísticos.

# %%
df.dtypes    # tipo de variables
# Out:
# Region                       object
# District                     object
# Place                        object
# 4_6_years_men                 int64
# 4_6_years_women               int64
# 4_6_years_total               int64
# 6_14_years_men              float64
# 6_14_years_women              int64
# 6_14_years_total              int64
# man_read                      int64
# women_read                  float64
# total_read                    int64
# men_not_read                  int64
# women_not_read                int64
# total_not_read              float64
# man_write                   float64
# women_write                 float64
# total_write                 float64
# men_not_write               float64
# women_not_write               int64
# total_not_write             float64
# instruction_men               int64
# instruction_women           float64
# instruction_total           float64
# no_instruction_men          float64
# no_instruction_women          int64
# ...

# %%
df.describe()    # principales estadísticos de las variable numéricas
# Out:
#        4_6_years_men  4_6_years_women  4_6_years_total  6_14_years_men  \
# count     197.000000       197.000000       197.000000      196.000000
# mean       16.979695        15.345178        32.324873       79.127551
# std        22.571419        21.618979        43.489455      100.078118
# min         0.000000         0.000000         0.000000        0.000000
# 25%         4.000000         4.000000         8.000000       25.000000
# 50%        10.000000         9.000000        20.000000       55.000000
# 75%        20.000000        18.000000        39.000000       88.250000
# max       184.000000       184.000000       368.000000      950.000000
#
#        6_14_years_women  6_14_years_total    man_read  women_read  total_read  \
# count        197.000000        197.000000  197.000000  193.000000  197.000000
# mean          62.482234        141.538071   34.654822   11.948187   46.360406
# std           90.879972        188.535210   51.091581   34.994455   83.291516
# ...

# %%
df.median(numeric_only=True)    # mediana de columnas numéricas
# Out:
# 4_6_years_men                10.0
# 4_6_years_women               9.0
# 4_6_years_total              20.0
# 6_14_years_men               55.0
# 6_14_years_women             41.0
# 6_14_years_total             91.0
# man_read                     21.0
# women_read                    0.0
# total_read                   23.0
# men_not_read                 41.0
# women_not_read               45.0
# total_not_read               84.0
# man_write                    12.0
# women_write                   0.0
# total_write                  13.0
# men_not_write                50.0
# women_not_write              48.0
# total_not_write              97.0
# instruction_men               9.0
# instruction_women             0.0
# instruction_total            13.0
# no_instruction_men           48.0
# no_instruction_women         50.0
# no_instruction_total         94.0
# finished_instr_men            0.0
# finished_instr_women          0.0
# finished_instr_total          0.0
# ...

# %%
df.mode(axis=0).iloc[0]    # moda de cada columna (tanto numéricas o no numéricas) y se muestra la primera fila
# Out:
# Region                                 JUNIN
# District                    CIUDAD DEL CERRO
# Place                                  CACAS
# 4_6_years_men                            2.0
# 4_6_years_women                          0.0
# 4_6_years_total                          8.0
# 6_14_years_men                          21.0
# 6_14_years_women                         0.0
# 6_14_years_total                        42.0
# man_read                                 0.0
# women_read                               0.0
# total_read                               0.0
# men_not_read                            25.0
# women_not_read                           0.0
# total_not_read                          50.0
# man_write                                0.0
# women_write                              0.0
# total_write                              0.0
# men_not_write                           25.0
# women_not_write                         25.0
# total_not_write                         50.0
# ...

# %% [markdown]
# #### 3. Verifique si las columnas presentan missing values.

# %%
df.isnull().sum(axis = 0)    # muestra cantidad todal de missing values por columnas
# Out:
# Region                       0
# District                     0
# Place                       11
# 4_6_years_men                0
# 4_6_years_women              0
# 4_6_years_total              0
# 6_14_years_men               1
# 6_14_years_women             0
# 6_14_years_total             0
# man_read                     0
# women_read                   4
# total_read                   0
# men_not_read                 0
# women_not_read               0
# total_not_read               1
# man_write                    1
# women_write                  1
# total_write                  5
# men_not_write                6
# women_not_write              0
# total_not_write              3
# instruction_men              0
# instruction_women            2
# instruction_total            2
# no_instruction_men           3
# no_instruction_women         0
# no_instruction_total         0
# finished_instr_men           3
# finished_instr_women         5
# finished_instr_total         1
# ...

# %% [markdown]
# #### 4. Cambie el nombre de las siguientes variables:
# place : comunidad
#
# men_not_read: homxlee
#
# women_not_read: mujerxlee
#
# total_not_read: totalxlee

# %%
df.rename(columns={"Place":"comunidad", "men_not_read":"homxlee", "women_not_read":"mujerxlee", "total_not_read":"totalxlee" }, inplace=True)
df
# Out:
#     Region          District           comunidad  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1    JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2    JUNIN  CIUDAD DEL CERRO                VICO              1
# 3    JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4    JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..     ...               ...                 ...            ...
# 192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193  JUNIN             YAULI         P.POMACOCHA              1
# 194  JUNIN             YAULI                 NaN              2
# 195  JUNIN             YAULI               YAULI              2
# 196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111           297.0               171
# ...

# %% [markdown]
# #### 5. Muestre los valores únicos de las siguientes variables ( comunidad , District)

# %%
df.comunidad.unique()
# Out:
# array(['C.CIUDAD DEL CERRO', 'P.YANACANCHA', 'VICO', 'RANCA', 'PASCO',
#        nan, 'CAJAMARQUILLA', 'CAICO', 'ROCO', 'P.QUINUA', 'H.PARIAHUANCA',
#        'P.SULLUMARCA', 'H.SAN ANDRÉS', 'P.HUALLAY', 'C.HUAYCHAO',
#        'COCHAMARCA', 'P.CHACAYÁN', 'VILCABAMBA', 'CUCHES', 'CHANGO',
#        'MITO', 'ANTAPIRCA', 'P.CAYNA', 'A. COLPAS', 'C.MASQUIN',
#        'P.YAMOR', 'TANGOR', 'QUIO', 'CAURY', 'CHUCCHUC', 'COQUIN',
#        'A.YAPOC', 'P.YANAHUANCA', 'HUAYLACIRCA', 'HUARANTAMBO',
#        'ANDUCHACA', 'VILLO', 'MICHIVILCA', 'PILLAO', 'YACÁN', 'TÁPUC',
#        'CHAUPIMARCA', 'P.OXAPAMPA', 'P.JAUJA', 'A.CHUNÁN', 'C.PACAPACHA',
#        'HUANCAS', 'A.HUERTAS', 'PACA', 'MASMA', 'ATAURA', 'HUALÁ',
#        'JULCÁN', 'P.RICRÁN', 'A.PAUCÁN', 'P.APATA', 'HUAMALÍ',
#        'A.SAN LORENZO', 'PACUCHO', 'P.ORCOTUNA', 'A.VICSO', 'TISTES',
#        'P.HUARIPAMPA', 'A.PARCO', 'PACCHA', 'CANCHAPUNCO', 'C.ULLUSCA',
#        'CANCHAS', 'P.MUQUIYAUYO', 'MUQUI', 'P.ACOLLA', 'MARCO',
# ...

# %%
df.District.unique()
# Out:
# array(['CIUDAD DEL CERRO', 'HUAYLLAY', 'CHACAYÁN', 'CAYNA', 'YANAHUANCA',
#        'NINACACA', 'JAUJA', 'APATA', 'ORCOTUNA', 'HUARIPAMPA',
#        'MUQUIYAUYO', 'ACOLLA', 'CINCOS', 'MITO', 'LLOCLLAPAMPA',
#        'CONCEPCIÓN', 'COCHAS', 'MATAHUASI', 'HUANCAYO', 'CHUPACA',
#        'SAN GERÓNIMO', 'SAPALLANGA', 'CHONGOS', 'SICAYA', 'COLCA',
#        'HUAYUCACHI', 'TARMA', 'JUNÍN', 'ACOBAMBA', 'OROYA', 'CARHUAMAYO',
#        'CHANCHAMAYO', 'VITOC', 'CHACAPALCA', 'YAULI'], dtype=object)

# %% [markdown]
# #### 6. Crear columnas con las siguiente información: el % de mujeres del que no escriben ni leen (mujerxlee/totalxlee) % de varones que no escriben ni leen (homxlee/totalxlee) y % de nativos respecto al total de la población. Para el total de la población sumar (peruvian_men + peruvian_women + foreign_men + foreign_women)

# %%
mujer_noescribenilee = df.mujerxlee/df.totalxlee
mujer_noescribenilee
# Out:
# 0      0.412104
# 1      0.714286
# 2      0.531915
# 3      1.000000
# 4      0.531915
#          ...
# 192    0.000000
# 193    0.466667
# 194    0.318182
# 195    0.385965
# 196    0.254237
# Length: 197, dtype: float64

# %%
df['mujer_noescribenilee'] = df['mujerxlee'] / df['totalxlee']
df['hombre_noescribenilee'] = df['homxlee'] / df['totalxlee']
df['nativos_porcentaje'] = df['mujerxlee'] / ( df['peruvian_men'] + df['peruvian_men'] + df['foreign_men'] + df['foreign_women'] )
df
# Out:
#     Region          District           comunidad  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1    JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2    JUNIN  CIUDAD DEL CERRO                VICO              1
# 3    JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4    JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..     ...               ...                 ...            ...
# 192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193  JUNIN             YAULI         P.POMACOCHA              1
# 194  JUNIN             YAULI                 NaN              2
# 195  JUNIN             YAULI               YAULI              2
# 196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111           297.0               171
# ...

# %% [markdown]
# #### 7. Crear una base de datos con la siguiente información:

# %% [markdown]
# a. Quedarse con la información de los distritos de Ciudad del Cerro, Jauja, Acolla, San Gerónimo, Tarma, Oroya y Concepción

# %%
df2 = df[df["District"].isin(['CIUDAD DEL CERRO', 'JAUJA', 'ACOLLA', 'SAN GERÓNIMO', 'TARMA', 'OROYA', 'CONCEPCIÓN'])]
df2
# Out:
#     Region          District                    comunidad  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO           C.CIUDAD DEL CERRO             65
# 1    JUNIN  CIUDAD DEL CERRO                 P.YANACANCHA              1
# 2    JUNIN  CIUDAD DEL CERRO                         VICO              1
# 3    JUNIN  CIUDAD DEL CERRO                        RANCA              0
# 4    JUNIN  CIUDAD DEL CERRO                        PASCO              4
# 5    JUNIN  CIUDAD DEL CERRO                          NaN              6
# 6    JUNIN  CIUDAD DEL CERRO                CAJAMARQUILLA              9
# 7    JUNIN  CIUDAD DEL CERRO                        CAICO             18
# 8    JUNIN  CIUDAD DEL CERRO                         ROCO              7
# 9    JUNIN  CIUDAD DEL CERRO                          NaN             16
# 10   JUNIN  CIUDAD DEL CERRO                     P.QUINUA              8
# 11   JUNIN  CIUDAD DEL CERRO                H.PARIAHUANCA              2
# ...

# %% [markdown]
# b. Luego quedarse con las comunidades que cuentan con nativos y mestizos.

# %%
df2 = df2.loc[(df["natives"] > 0) & (df["mestizos"] > 0)]
df2
# Out:
#     Region          District                comunidad  4_6_years_men  \
# 0    JUNIN  CIUDAD DEL CERRO       C.CIUDAD DEL CERRO             65
# 2    JUNIN  CIUDAD DEL CERRO                     VICO              1
# 3    JUNIN  CIUDAD DEL CERRO                    RANCA              0
# 4    JUNIN  CIUDAD DEL CERRO                    PASCO              4
# 5    JUNIN  CIUDAD DEL CERRO                      NaN              6
# 7    JUNIN  CIUDAD DEL CERRO                    CAICO             18
# 13   JUNIN  CIUDAD DEL CERRO             H.SAN ANDRÉS              8
# 47   JUNIN             JAUJA                  P.JAUJA             69
# 51   JUNIN             JAUJA                A.HUERTAS             22
# 53   JUNIN             JAUJA                    MASMA             27
# 54   JUNIN             JAUJA                   ATAURA             24
# 55   JUNIN             JAUJA                    HUALÁ              9
# 56   JUNIN             JAUJA                   JULCÁN             19
# ...

# %% [markdown]
# c. Solo quedarse con las variables trabajadas en el punto 6), nombre de distrito y comunidad.

# %%
df2.columns
# Out:
# Index(['Region', 'District', 'comunidad', '4_6_years_men', '4_6_years_women',
#        '4_6_years_total', '6_14_years_men', '6_14_years_women',
#        '6_14_years_total', 'man_read', 'women_read', 'total_read', 'homxlee',
#        'mujerxlee', 'totalxlee', 'man_write', 'women_write', 'total_write',
#        'men_not_write', 'women_not_write', 'total_not_write',
#        'instruction_men', 'instruction_women', 'instruction_total',
#        'no_instruction_men', 'no_instruction_women', 'no_instruction_total',
#        'finished_instr_men', 'finished_instr_women', 'finished_instr_total',
#        'not_finished_instr_men', 'not_finished_instr_women',
#        'not_finished_instr_total', 'peruvian_men', 'peruvian_women',
#        'foreign_men', 'foreign_women', 'whites', 'natives', 'mestizos',
#        'blacks', 'mujer_noescribenilee', 'hombre_noescribenilee',
#        'nativos_porcentaje'],
#       dtype='object')

# %%
df3 = df2[['homxlee', 'mujerxlee', 'totalxlee', 'District', 'comunidad']]
df3.reset_index(drop=True, inplace=True)    
df3
# Out:
#     homxlee  mujerxlee  totalxlee          District                comunidad
# 0       204        143      347.0  CIUDAD DEL CERRO       C.CIUDAD DEL CERRO
# 1        22         25       47.0  CIUDAD DEL CERRO                     VICO
# 2         0         25       25.0  CIUDAD DEL CERRO                    RANCA
# 3        22         25       47.0  CIUDAD DEL CERRO                    PASCO
# 4        37         46       83.0  CIUDAD DEL CERRO                      NaN
# 5        74         78      152.0  CIUDAD DEL CERRO                    CAICO
# 6        22         25       47.0  CIUDAD DEL CERRO             H.SAN ANDRÉS
# 7       179        217      396.0             JAUJA                  P.JAUJA
# 8        41        114      155.0             JAUJA                A.HUERTAS
# 9        85        147      232.0             JAUJA                    MASMA
# 10       61         74      135.0             JAUJA                   ATAURA
# ...

# %% [markdown]
# d. Guardar la base de datos en formato csv en la carpeta data. (Use el siguiente nombre Base_cleaned_WG(numero de grupo))

# %%
junin_data = df3

junin_data.to_csv (r'../data/Base_cleaned_WG7_ISSUE3.csv', index = False)

# %% [markdown]
# ## 2. Crear una función para reescalar los datos de un vector y de las columnas de una matriz. El vector debe contar con 100 observaciones y la matriz 100 x 50.

# %%
# Reescalando un vector

vector = np.arange(100)

def reescalar (x, min, max):
    
    out = (x - min) / (max - min)
    
    return out    

list( map( lambda x, min = np.min(vector), max = np.max(vector): reescalar(x, min, max), vector)  )
# Out:
# [0.0,
#  0.010101010101010102,
#  0.020202020202020204,
#  0.030303030303030304,
#  0.04040404040404041,
#  0.050505050505050504,
#  0.06060606060606061,
#  0.0707070707070707,
#  0.08080808080808081,
#  0.09090909090909091,
#  0.10101010101010101,
#  0.1111111111111111,
#  0.12121212121212122,
#  0.13131313131313133,
#  0.1414141414141414,
#  0.15151515151515152,
#  0.16161616161616163,
#  0.1717171717171717,
#  0.18181818181818182,
#  0.1919191919191919,
#  0.20202020202020202,
#  0.21212121212121213,
#  0.2222222222222222,
#  0.23232323232323232,
#  0.24242424242424243,
#  0.25252525252525254,
#  0.26262626262626265,
#  0.2727272727272727,
#  0.2828282828282828,
#  0.29292929292929293,
#  0.30303030303030304,
#  0.31313131313131315,
#  0.32323232323232326,
#  0.3333333333333333,
#  0.3434343434343434,
#  0.35353535353535354,
#  0.36363636363636365,
#  0.37373737373737376,
#  0.3838383838383838,
#  0.3939393939393939,
#  0.40404040404040403,
#  0.41414141414141414,
# ...

# %%
# creando matriz

np.random.seed(15632)
x1 = np.random.rand(100) # uniform distribution  [0,1]
x2 = np.random.rand(100) # uniform distribution [0,1]
x3 = np.random.rand(100) # uniform distribution [0,1]
x4 = np.random.rand(100) # uniform distribution [0,1]
X = np.column_stack((np.ones(100),x1,x2,x3,x4))

# Reescalando una matriz
X_reescaled = np.apply_along_axis(lambda x: (x-x.min()) / (x.max()-x.min()), 0, X)
X_reescaled
# Out:
# /var/folders/zl/dwjs19r53hv4ng4wbr0b4srm0000gn/T/ipykernel_2502/2154221274.py:11: RuntimeWarning: invalid value encountered in true_divide
#   X_reescaled = np.apply_along_axis(lambda x: (x-x.min()) / (x.max()-x.min()), 0, X)
# array([[       nan, 0.33819077, 0.6474859 , 0.84476697, 0.06360999],
#        [       nan, 0.42689888, 0.34456686, 0.98325172, 0.03350936],
#        [       nan, 0.30029946, 0.41386637, 0.07762547, 0.57635043],
#        [       nan, 0.79769974, 0.16462878, 0.47270122, 0.84895149],
#        [       nan, 0.67152409, 0.9783949 , 0.18258883, 0.51389193],
#        [       nan, 0.12001369, 0.38267602, 0.489694  , 0.55770878],
#        [       nan, 0.42766886, 0.68528743, 0.63564371, 0.33515845],
#        [       nan, 0.28617896, 0.22707753, 0.43690556, 0.77653679],
#        [       nan, 0.18005057, 0.91234694, 0.5559983 , 0.93643101],
#        [       nan, 0.77812338, 0.09012318, 0.48292083, 0.36356362],
# ...

# %% [markdown]
# ## 3. Keywords especiales (*args and *kwargs)
# Construya una función que permite realizar las siguientes operaciones a un vector: estandarizar y reescalar (función del ejercicio 2). Use **kwargs para definir estas operaciones y *args para el vector.

# %%
# Creamos la función "calculator" que estandarizará y reescalara un vector

def calculator( *args, **kwargs):
    
    vector = np.array( list(args) )  # transforma *args a lista, luego la transforma en un array
    
    if ( kwargs[ 'function' ] == "estandarizar" ) :
        # Get the first value
        def reescalar (x, mean, std):
            out = (x - mean) / std
            return out
        
        result = list( map( lambda x, mean = np.mean(vector), std = np.std(vector): reescalar(x, mean, std), vector)  )
    
    elif ( kwargs[ 'function' ] == "reescalar" ) :
        # Get the second value
        def reescalar (x, min, max):
            out = (x - min) / (max - min)
            return out
        
        result = list( map( lambda x, min = np.min(vector), max = np.max(vector): reescalar(x, min, max), vector)  ) 
        
    else:
        raise ValueError( f"The function argument {kwargs[ 'function' ]} is not supported." )
        # Mensaje de error por tipo de argumento

    return result

# %%
calculator(np.arange(80), function='estandarizar')
# Out:
# [array([-1.71053381, -1.66722916, -1.62392451, -1.58061985, -1.5373152 ,
#         -1.49401055, -1.45070589, -1.40740124, -1.36409659, -1.32079193,
#         -1.27748728, -1.23418262, -1.19087797, -1.14757332, -1.10426866,
#         -1.06096401, -1.01765936, -0.9743547 , -0.93105005, -0.8877454 ,
#         -0.84444074, -0.80113609, -0.75783144, -0.71452678, -0.67122213,
#         -0.62791748, -0.58461282, -0.54130817, -0.49800352, -0.45469886,
#         -0.41139421, -0.36808955, -0.3247849 , -0.28148025, -0.23817559,
#         -0.19487094, -0.15156629, -0.10826163, -0.06495698, -0.02165233,
#          0.02165233,  0.06495698,  0.10826163,  0.15156629,  0.19487094,
#          0.23817559,  0.28148025,  0.3247849 ,  0.36808955,  0.41139421,
#          0.45469886,  0.49800352,  0.54130817,  0.58461282,  0.62791748,
#          0.67122213,  0.71452678,  0.75783144,  0.80113609,  0.84444074,
#          0.8877454 ,  0.93105005,  0.9743547 ,  1.01765936,  1.06096401,
# ...

# %%
calculator(np.arange(80), function='reescalar')
# Out:
# [array([0.        , 0.01265823, 0.02531646, 0.03797468, 0.05063291,
#         0.06329114, 0.07594937, 0.08860759, 0.10126582, 0.11392405,
#         0.12658228, 0.13924051, 0.15189873, 0.16455696, 0.17721519,
#         0.18987342, 0.20253165, 0.21518987, 0.2278481 , 0.24050633,
#         0.25316456, 0.26582278, 0.27848101, 0.29113924, 0.30379747,
#         0.3164557 , 0.32911392, 0.34177215, 0.35443038, 0.36708861,
#         0.37974684, 0.39240506, 0.40506329, 0.41772152, 0.43037975,
#         0.44303797, 0.4556962 , 0.46835443, 0.48101266, 0.49367089,
#         0.50632911, 0.51898734, 0.53164557, 0.5443038 , 0.55696203,
#         0.56962025, 0.58227848, 0.59493671, 0.60759494, 0.62025316,
#         0.63291139, 0.64556962, 0.65822785, 0.67088608, 0.6835443 ,
#         0.69620253, 0.70886076, 0.72151899, 0.73417722, 0.74683544,
#         0.75949367, 0.7721519 , 0.78481013, 0.79746835, 0.81012658,
#         0.82278481, 0.83544304, 0.84810127, 0.86075949, 0.87341772,
# ...
